# %% [markdown]
# # CARGA DE ARCHIVOS

# %%
import sys

sys.path.insert(0,'/home/grias/HP/ACTUAL/REALES CODIFICACION/Scripts')

from ClasesOPDP import *

# %%
sync_reasoner()
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /home/grias/anaconda3/envs/tg/lib/python3.8/site-packages/owlready2/hermit:/home/grias/anaconda3/envs/tg/lib/python3.8/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpz_788psp
# * Owlready2 * HermiT took 4.107873201370239 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
# perro = (ontologia.Palabra.instances())[0]
# trabajo = (perro.palabra_describe_pi)[0]
# trabajo.get_tipo_proyecto_investigacion()
# Out:
# ['Docente 2017']

# %%
# print(trabajo.is_a)
# #print(ontologia.get_instances_of(parent))
# print(ontologia.get_parents_of(Facultad))
# print(ontologia.get_children_of(Universidad))
# Out:
# [OntologiaInvestigacionPrueba.Proyecto_investigacion]
# [OntologiaInvestigacionPrueba.Universidad]
# [OntologiaInvestigacionPrueba.VIIS, OntologiaInvestigacionPrueba.Facultad]

# %%
graph = default_world.as_rdflib_graph()

# %%
consulta0 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?subject ?object
    WHERE { ?subject rdfs:subClassOf ?object }
    limit 1
"""))

consulta0
# Out:
# [[OntologiaInvestigacionPrueba.Convocatoria,
#   OntologiaInvestigacionPrueba.VIIS]]

# %%
consulta1 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>


SELECT ?Proyecto
    WHERE { ?Proyecto on:pi_tiene_palabra on:buscador.}
"""))
consulta1
# len(consulta[0])
# consulta[0].get_titulo_proyecto_investigacion()
# len(consulta)
# print(consulta[0].get_titulo_proyecto_investigacion())
# print(consulta)
# Out:
# []

# %%
ontologia.pi427.get_titulo_proyecto_investigacion()
# Out:
# ['OBTENCIÓN DE ÁCIDO L (+)- LÁCTICO A PARTIR DE HIDROLIZADOS DE RESIDUOS DE PAPA UTILIZANDO Lactobacillus casei COMO ORGANISMO FERMENTADOR.']

# %%
consulta2 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT ?Proyecto
WHERE { ?Proyecto on:palabra_describe_pi on:pi427. } 
LIMIT 100
"""))

consulta2
# Out:
# [[OntologiaInvestigacionPrueba.escolarizados]]

# %%
consulta3 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT  ?Proyecto ?Palabra
WHERE { ?Proyecto on:palabra_describe_pi ?Palabra. }
"""))
consulta3
# Out:
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.i.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.e . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.c . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.s.p . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.d . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#l.f . does not look like a valid URI, trying to serialize this will break.
# ...

# %%
list(ontologia.Palabra.instances())
# Out:
# [OntologiaInvestigacionPrueba.solucionar,
#  OntologiaInvestigacionPrueba.latente,
#  OntologiaInvestigacionPrueba.académico,
#  OntologiaInvestigacionPrueba.modalidad,
#  OntologiaInvestigacionPrueba.generar,
#  OntologiaInvestigacionPrueba.industriar,
#  OntologiaInvestigacionPrueba.reconocimiento,
#  OntologiaInvestigacionPrueba.cambio,
#  OntologiaInvestigacionPrueba.formar,
#  OntologiaInvestigacionPrueba.afrontar,
#  OntologiaInvestigacionPrueba.consolidación,
#  OntologiaInvestigacionPrueba.situación,
#  OntologiaInvestigacionPrueba.humanar,
#  OntologiaInvestigacionPrueba.cambiar,
#  OntologiaInvestigacionPrueba.interesar,
#  OntologiaInvestigacionPrueba.pertinente,
#  OntologiaInvestigacionPrueba.emprendimiento,
#  OntologiaInvestigacionPrueba.integral,
#  OntologiaInvestigacionPrueba.génesis,
#  OntologiaInvestigacionPrueba.estratégico,
#  OntologiaInvestigacionPrueba.institución,
#  OntologiaInvestigacionPrueba.desarrollo,
#  OntologiaInvestigacionPrueba.sociedad,
# ...

# %%
consulta4 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT  ?id?titulo?pi(count(?id) as ?c)
WHERE {?pi po:pi_tiene_palabra ?palabra.

       # ?palabra po:descripcion_palabra ?descripcion
       
       FILTER(
       REGEX(str(?descripcion),'descubrimiento','i')       
       )

}

group_by 
"""))
consulta4

# %%
consulta5 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT  ?pi
WHERE {?pi on:pi_tiene_palabra ?palabra.

       # ?palabra on:descripcion_palabra ?descripcion
       
       FILTER(
       REGEX(str(?descripcion),'descubrimiento')||
       REGEX(str(?descripcion),'conocimiento')
       
       )

}

"""))
consulta5
# Out:
# [[OntologiaInvestigacionPrueba.pi144]]

# %%
consulta6 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT  ?palabra1, ?palabra2
WHERE { ?palabra1 on:palabra_conecta_palabra ?palabra2.}
"""))
consulta6
# len(consulta6)
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-21-1b2b82b6cb8b> in <module>
# ----> 1 consulta6 = list(graph.query_owlready("""
#       2 PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#       3 PREFIX owl: <http://www.w3.org/2002/07/owl#>
#       4 PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#       5 PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# ~/anaconda3/envs/tg/lib/python3.8/site-packages/owlready2/rdflib_store.py in query_owlready(self, query, *args, **kargs)
#     266   onto = None
#     267   def query_owlready(self, query, *args, **kargs):
# --> 268     r = self.query(query, *args, **kargs)
#     269     for line in r:
#     270       line2 = [self._rdflib_2_owlready(i) for i in line]
#
# ...

# %%
consulta3 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT  ?Proyecto ?Palabra
WHERE { ?Proyecto on:pi_tiene_palabra ?Palabra. }
"""))
# Out:
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.i.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.e . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#d.c . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.a . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#e.s.p . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#s.d . does not look like a valid URI, trying to serialize this will break.
# http://www.semanticweb.org/OntologiaInvestigacionPrueba#l.f . does not look like a valid URI, trying to serialize this will break.
# ...

# %%
consulta3
# Out:
# [[OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.solucionar],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.latente],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.académico],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.modalidad],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.generar],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.industriar],
#  [OntologiaInvestigacionPrueba.pi1,
#   OntologiaInvestigacionPrueba.reconocimiento],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.cambio],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.formar],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.afrontar],
#  [OntologiaInvestigacionPrueba.pi1,
#   OntologiaInvestigacionPrueba.consolidación],
#  [OntologiaInvestigacionPrueba.pi1, OntologiaInvestigacionPrueba.situación],
# ...

# %%
consulta3 = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT  ?Proyecto
WHERE { ?Proyecto on:pi_tiene_palabra po:e.g .}
"""))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-30-fe8eef5c3cfd> in <module>
# ----> 1 consulta3 = list(graph.query_owlready("""
#       2 PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#       3 PREFIX owl: <http://www.w3.org/2002/07/owl#>
#       4 PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#       5 PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# ~/anaconda3/envs/tg/lib/python3.8/site-packages/owlready2/rdflib_store.py in query_owlready(self, query, *args, **kargs)
#     266   onto = None
#     267   def query_owlready(self, query, *args, **kargs):
# --> 268     r = self.query(query, *args, **kargs)
#     269     for line in r:
#     270       line2 = [self._rdflib_2_owlready(i) for i in line]
#
# ...

# %%
import jaydebeapi
# jclass = "org.apache.jena.jdbc.JenaJDBC"
# conn_string = "jdbc:jena:tdb:location=/path/to/tdbstore"
# conn = jaydebeapi.connect(jclass, conn_string)
# cursor = conn.cursor()
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>
SELECT  ?Proyecto ?Palabra
WHERE { ?Proyecto on:pi_tiene_palabra ?Palabra. }
"""

# %%
query

# %%
graph = default_world.as_rdflib_graph()

# %%
ej_consulta = list(graph.query_owlready("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX onto: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT ?Proyecto
    WHERE { ?Proyecto onto:pi_tiene_palabra onto:motor.}
"""))
ej_consulta
# Out:
# [[OntologiaInvestigacionPrueba.pi79],
#  [OntologiaInvestigacionPrueba.pi260],
#  [OntologiaInvestigacionPrueba.pi398],
#  [OntologiaInvestigacionPrueba.pi427]]

# %%
ontologia.pi427.get_titulo_proyecto_investigacion()
# Out:
# ['MOTOR DE BÚSQUEDA INTELIGENTE DE INFORMES DE INVESTIGACIÓN BASADO EN RECURSOS SEMÁNTICOS PARA EL SISTEMA DE INVESTIGACIONES DE LA UNIVERSIDAD DE NARIÑO']

# %% [markdown]
# # NUEVAS CONSULTAS SOBRE TODAS LAS INSTANCIAS Y RELACIONES

# %%
#gi_tiene_li

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?gi ?li
WHERE {?gi on:gi_tiene_li ?li.
}

# %%
#gi_tiene_docente

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?gi ?docente
WHERE {?gi on:gi_tiene_docente ?docente.
}

# %%
#gi_tiene_estudiante

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?gi ?estudiante
WHERE {?gi on:gi_tiene_estudiante ?estudiante.
}

# %%
#li_tiene_pi

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?li ?pi
WHERE {?li on:li_tiene_pi ?pi.
}

# %%
#docente_es_autor_pi

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?docente ?pi
WHERE {?docente on:docente_es_autor_pi ?pi.
}

# %%
#docente_asesora_pi

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?docente ?pi
WHERE {?docente on:docente_asesora_pi ?pi.
}

# %%
#estudiante_es_autor_pi

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?estudiante ?pi
WHERE {?estudiante on:estudiante_es_autor_pi ?pi.
}

# %%
#ie_es_autor_pi

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?ie ?pi
WHERE {?ie on:ie_es_autor_pi ?pi.
}

# %%
#facultad_tiene_departamento

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?facultad ?departamento
WHERE {?facultad on:facultad_tiene_departamento ?departamento.
}

# %%
#departamento_tiene_gi

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?departamento ?gi
WHERE {?departamento on:departamento_tiene_gi ?gi.
}

# %%
#programa_tiene_estudiante

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?programa ?estudiante
WHERE {?programa on:programa_tiene_estudiante ?estudiante.
}

# %%
#programa_tiene_estudiante2

# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

# SELECT  ?programa ?estudiante ?nombre_programa
# WHERE {?programa on:programa_tiene_estudiante ?estudiante.
#   ?programa on:nombre_programa ?nombre_programa
#}

# %%
# programa_tiene_docente

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?programa ?docente
WHERE {?programa on:programa_tiene_docente ?docente.
}

# %%
# departamento_tiene_programa

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?departamento ?programa
WHERE {?departamento on:departamento_tiene_programa ?programa.
}

# %%
# convocatoria_tiene_pi

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX on: <http://www.semanticweb.org/OntologiaInvestigacionPrueba#>

SELECT  ?convocatoria ?pi
WHERE {?convocatoria on:convocatoria_tiene_pi ?pi.
}
